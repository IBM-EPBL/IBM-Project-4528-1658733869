# %%
test_dir=r"C:\project\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set"

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r"C:\Users\R.Dharun pandian\vegetabledata.h5")

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\project\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Tomato___Late_blight\b07f5c6e-2e85-4b45-a166-522cc484619c___RS_Late.B 6276.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1636EAE7460>

# %%
img=image.load_img(r"C:\project\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Tomato___Late_blight\b07f5c6e-2e85-4b45-a166-522cc484619c___RS_Late.B 6276.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot','Potato___Late_blight','Potato___healthy','Tomato___Bacterial_spot','Tomato___Late_blight']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 'Tomato___Late_blight'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 5s 93ms/step - loss: 2286.1699 - accuracy: 0.2920
# [2286.169921875, 0.2919999957084656]
